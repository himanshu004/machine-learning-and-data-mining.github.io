# %%
# translation

import numpy as np
import matplotlib.pyplot as plt

size = int(input('Enter the number of coordinates:'))
mat = np.ones(3 * size,dtype = 'int').reshape(size,3)

print('Enter the co-ordinates:')
for i in range(0,size):
        x,y = (map(int,input().split()))
        mat[i][0] = x
        mat[i][1] = y
        
print('The matrix you entered is:')
print(mat)

x = mat[:,0]
new_x = np.append(x,x[0])
y = mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
    
tx = int(input('Enter tx:'))
ty = int(input('Enter ty:'))

t = np.array([[1,0,1],[0,1,0],[tx,ty,1]])
new_mat = mat.dot(t)

print('The matrix after translation is:')
print(new_mat)

x = new_mat[:,0]
new_x = np.append(x,x[0])
y = new_mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
# Out:
# Enter the number of coordinates:3
# Enter the co-ordinates:
# 1 3
# 2 3
# 4 5
# The matrix you entered is:
# [[1 3 1]
#  [2 3 1]
#  [4 5 1]]
# Enter tx:3
# Enter ty:2
# The matrix after translation is:
# [[4 5 2]
#  [5 5 3]
#  [7 7 5]]

# %%
# scaling

import numpy as np
import matplotlib.pyplot as plt

size = int(input('Enter the number of coordinates:'))
mat = np.zeros(2 * size,dtype = 'int').reshape(size,2)

print('Enter the co-ordinates:')
for i in range(0,size):
        x,y = (map(int,input().split()))
        mat[i][0] = x
        mat[i][1] = y
        
print('The matrix you entered is:')
print(mat)

x = mat[:,0]
new_x = np.append(x,x[0])
y = mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
    
sx = int(input('Enter Sx:'))
sy = int(input('Enter Sy:'))

t = np.array([[sx,0],[0,sy]])
new_mat = mat.dot(t)

print('The matrix after scaling is:')
print(new_mat)

x = new_mat[:,0]
new_x = np.append(x,x[0])
y = new_mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
# Out:
# Enter the number of coordinates:3
# Enter the co-ordinates:
# 2 3
# 4 5
# 1 2
# The matrix you entered is:
# [[2 3]
#  [4 5]
#  [1 2]]
# Enter Sx:3
# Enter Sy:2
# The matrix after scaling is:
# [[ 6  6]
#  [12 10]
#  [ 3  4]]

# %%
### rotation

import numpy as np
import matplotlib.pyplot as plt
import math

size = int(input('Enter the number of coordinates:'))
mat = np.ones(3 * size,dtype = 'int').reshape(size,3)

print('Enter the co-ordinates:')
for i in range(0,size):
        x,y = (map(int,input().split()))
        mat[i][0] = x
        mat[i][1] = y
        
print('The matrix you entered is:')
print(mat)


x = mat[:,0]
new_x = np.append(x,x[0])
y = mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
    
ch = int(input('Clockwise(0) or Anti-clockwise(1)?'))
theta = float(input('Enter the value of theta (in degrees)'))
theta *= math.pi / 180

if(ch == 0):
    t = np.array([[math.cos(theta),-math.sin(theta),0],[math.sin(theta),math.cos(theta),0],[0,0,1]])
else:
    t = np.array([[math.cos(theta),math.sin(theta),0],[-math.sin(theta),math.cos(theta),0],[0,0,1]])
    
new_mat = mat.dot(t)

print('The matrix after rotation is:')
print(new_mat)

x = new_mat[:,0]
new_x = np.append(x,x[0])
y = new_mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
# Out:
# Enter the number of coordinates:3
# Enter the co-ordinates:
# 1 3
# 3 2
# 4 6
# The matrix you entered is:
# [[1 3 1]
#  [3 2 1]
#  [4 6 1]]
# Clockwise(0) or Anti-clockwise(1)?1
# Enter the value of theta (in degrees)45
# The matrix after rotation is:
# [[-1.41421356  2.82842712  1.        ]
#  [ 0.70710678  3.53553391  1.        ]
#  [-1.41421356  7.07106781  1.        ]]

# %%
### reflection

import numpy as np
import matplotlib.pyplot as plt
import math

size = int(input('Enter the number of coordinates:'))
mat = np.ones(3 * size,dtype = 'int').reshape(size,3)

print('Enter the co-ordinates:')
for i in range(0,size):
        x,y = (map(int,input().split()))
        mat[i][0] = x
        mat[i][1] = y
        
print('The matrix you entered is:')
print(mat)


x = mat[:,0]
new_x = np.append(x,x[0])
y = mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
    
ch = int(input('About X-axis(0) or Y-axis(1)?'))

if(ch == 0):
    t = np.array([[1,0,0],[0,-1,0],[0,0,1]])
else:
    t = np.array([[-1,0,0],[0,1,0],[0,0,1]])
    
new_mat = mat.dot(t)

print('The matrix after reflection is:')
print(new_mat)

x = new_mat[:,0]
new_x = np.append(x,x[0])
y = new_mat[:,1]
new_y = np.append(y,y[0])

plt.plot(new_x,new_y,'b*--',markersize = 20,linewidth = 3)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()
# Out:
# Enter the number of coordinates:3
# Enter the co-ordinates:
# 1 2
# 3 4
# 4 2
# The matrix you entered is:
# [[1 2 1]
#  [3 4 1]
#  [4 2 1]]
# About X-axis(0) or Y-axis(1)?0
# The matrix after reflection is:
# [[ 1 -2  1]
#  [ 3 -4  1]
#  [ 4 -2  1]]
