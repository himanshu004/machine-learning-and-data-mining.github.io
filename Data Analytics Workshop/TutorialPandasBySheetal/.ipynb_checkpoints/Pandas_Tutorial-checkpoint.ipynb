# %% [markdown]
# The contents contained in this Jupyter notebook may be freely distributed for teaching-learning purpose. When more than 50% of this notebook is used for a presentation or distribution it may be cited as follows:
#
# Pandas Tutorial: developed by Sheetal Taneja (Assistant Professor, Dyal Singh College), Ankit Rajpal (Assistant Professor, Deen Dayal Upadhyaya College), Naveen Kumar (Professor, Department of Computer Science), University of Delhi.

# %% [markdown]
# # Pandas
#
# * High-level data manipulation and analysis tool developed by Wes McKinney.
# * Built on the Numpy package and its key data structure is called the DataFrame.
# * DataFrames allow you to store and manipulate tabular data in rows of observations and columns of variables.

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Series
# Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.).

# %%
#Creating Pandas Series using lists

animals = ['Tiger', 'Bear', 'Lion']
animalsDF = pd.Series(animals)
print(animalsDF)
# Out:
# 0    Tiger
# 1     Bear
# 2     Lion
# dtype: object

# %%
numbers = [10, 20, 30]
numSeries = pd.Series(numbers)
print(numSeries)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# #### Indexing

# %%
numSeries[2]
# Out:
# 30

# %%
animals = ['Tiger', 'Bear', None]
animalSeries = pd.Series(animals)
print(animalSeries)
# Out:
# 0    Tiger
# 1     Bear
# 2     None
# dtype: object

# %%
numbers = [1, 2, 3, 4, 5,  None]
numSeries = pd.Series(numbers)
numSeries
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
#Another way of creating a series
animals = ['Tiger', 'Bear', 'Lion']
animalSeries = pd.Series(animals, index = ['One', 'Two', 'Three'])
print(animalSeries)
# Out:
# One      Tiger
# Two       Bear
# Three     Lion
# dtype: object

# %%
animalSeries['Two']
# Out:
# 'Bear'

# %%
numbers = [1, 2, 3.2, 4.9, 5.5]
numSeries = pd.Series(numbers)
print('numSeries Before:')
print(numSeries)
numSeries = numSeries.astype(int)
print('\n\nnumSeries after:')
print(numSeries)
# Out:
# numSeries Before:
# 0    1.0
# 1    2.0
# 2    3.2
# 3    4.9
# 4    5.5
# dtype: float64
#
#
# numSeries after:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
#Index of a Series can be of String type
sportsDict = {'Archery': 'Bhutan',            
              'Golf': 'Scotland',
              'Sumo': 'Japan',
              'Hockey': 'India'}          #Creating Series from Dictionary

sports = pd.Series(sportsDict)
print(sports)
# Out:
# Archery      Bhutan
# Golf       Scotland
# Hockey        India
# Sumo          Japan
# dtype: object

# %%
print(sports['Archery'])
# Out:
# Bhutan

# %%
#dir(sports)
sports.values
# Out:
# array(['Bhutan', 'Scotland', 'India', 'Japan'], dtype=object)

# %%
sports.index
# Out:
# Index(['Archery', 'Golf', 'Hockey', 'Sumo'], dtype='object')

# %%
animals = ['Tiger', 'Bear', 'Lion']
nations = ['India', 'America', 'Sri Lanka']
nationalAnimals = pd.Series(animals, index = nations)
nationalAnimals
# Out:
# India        Tiger
# America       Bear
# Sri Lanka     Lion
# dtype: object

# %%
pd.Series(sports.index, index = sports.values)
# Out:
# Bhutan      Archery
# Scotland       Golf
# India        Hockey
# Japan          Sumo
# dtype: object

# %% [markdown]
# ### Querying a Series

# %%
sectionNames = ['A','B','C','D','E','F','G']

# %%
sectionStrength = [34,50,60,54,45,40, 50]

# %%
sections = pd.Series(sectionStrength, index = sectionNames)
print(sections)
# Out:
# A    34
# B    50
# C    60
# D    54
# E    45
# F    40
# G    50
# dtype: int64

# %%
sections.head()
# Out:
# A    34
# B    50
# C    60
# D    54
# E    45
# dtype: int64

# %%
help(sections.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n=5) method of pandas.core.series.Series instance
#     Return the first n rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     obj_head : type of caller
#         The first n rows of the caller object.

# %%
sections.head(3)
# Out:
# A    34
# B    50
# C    60
# dtype: int64

# %%
sections.tail()
# Out:
# B    50
# C    60
# D    54
# E    45
# F    40
# dtype: int64

# %%
print(sections)
#Querying a Series based on index location
sections.iloc[-1]
# Out:
# A    34
# B    50
# C    60
# D    54
# E    45
# F    40
# G    50
# dtype: int64
# 50

# %%
#Querying a Series based on index label

print(sections.loc['B'])
print(sections['B'])
# Out:
# 50
# 50

# %% [markdown]
# ## Operations on a Series

# %%
sections
# Out:
# A    34
# B    50
# C    60
# D    54
# E    45
# F    40
# dtype: int64

# %%
#Adding values of a series  using for loop:

def getClassStrength(sections):
    '''
    objective: to compute the strength of the class across the sections
        
    input: 
        sections: series comprising sections of a class
    output: 
        classStrength: total number of students across the sections
    '''
    '''
    approach: 
        initialize classStrength = 0  
        iterate through iteritems 
    '''
    classStrength = 0
    for item in sections:
        classStrength += item
    return classStrength

# %%
getClassStrength(sections)
# Out:
# 283

# %%
#Using numpy functions is much faster than for loops
print(sections.sum())
print(sections.mean())
# Out:
# 283
# 47.166666666666664

# %%
sections
# Out:
# A    34
# B    50
# C    60
# D    54
# E    45
# F    40
# G    50
# dtype: int64

# %%
#adds 5 to each value in Class using broadcasting - It is much faster

sections += 5 
sections
# Out:
# A    39
# B    55
# C    65
# D    59
# E    50
# F    45
# G    55
# dtype: int64

# %%
#Appending a Series to another Series

nationalSports = pd.Series({ 'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})


cricketLovingCountries = pd.Series(['Australia',
                                    'Barbados',
                                    'Pakistan',
                                    'England'], 
                                   index = ['Cricket',
                                            'Cricket',
                                            'Cricket',
                                            'Cricket'])
print(nationalSports, "\n\n", cricketLovingCountries)
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object
#
#  Cricket    Australia
# Cricket     Barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
allCountries = nationalSports.append(cricketLovingCountries)
allCountries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
allCountries.iloc[4]
# Out:
# 'Australia'

# %% [markdown]
# ## Pandas Dataframe
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects.

# %%
#Creating a Dataframe from multiple Series: Series indices are promoted to column headers 

import pandas as pd
purchase_1 = pd.Series({'Name': 'Ashish',
                        'Item Purchased': 'Bread',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Nikita',
                        'Item Purchased': 'Vegetables',
                        'Cost': 90.00})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Milk',
                        'Cost': 75.00})
print(purchase_1,"\n\n", purchase_2,"\n\n", purchase_3)
purchase = pd.DataFrame([purchase_1, purchase_2, purchase_3], index = [1, 2, 3])
purchase
# Out:
# Cost                22.5
# Item Purchased     Bread
# Name              Ashish
# dtype: object
#
#  Cost                      90
# Item Purchased    Vegetables
# Name                  Nikita
# dtype: object
#
#  Cost                 75
# Item Purchased     Milk
# Name              Vinod
# dtype: object
#    Cost Item Purchased    Name
# 1  22.5          Bread  Ashish
# 2  90.0     Vegetables  Nikita
# 3  75.0           Milk   Vinod

# %%
#Selecting a Column from a Dataframe
Names = purchase['Name']              
print(Names)
# Out:
# 1    Ashish
# 2    Nikita
# 3     Vinod
# Name: Name, dtype: object

# %%
data = [[22,'Bread'], [90, 'Vegetables'], [75, 'Milk']]
index = [0,1,2]

columns = ['Cost', 'Item Purchased']
foodCosts = pd.DataFrame(data, index=index, columns=columns)
foodCosts
# Out:
#    Cost Item Purchased
# 0    22          Bread
# 1    90     Vegetables
# 2    75           Milk

# %% [markdown]
# ## Dataframe Operations

# %%
#Reading a CSV file into a Dataframe
shopping = pd.read_csv("Grocery.csv")       
shopping
# Out:
#        Product    Category  Price  Quantity
# 0        Bread        Food     20         2
# 1         Milk        Food     60         5
# 2      Biscuit        Food     20         2
# 3   Bourn-Vita        Food     70         1
# 4        Maggi        Food     20         5
# 5          Tea        Food    120         1
# 6         Soap     Hygiene     40         4
# 7        Brush     Hygiene     30         2
# 8    Detergent   Household     80         1
# 9     Hair-Oil     Hygiene    100         1
# 10     Perfume     Hygiene    150         1
# 11  Tiffin Box   Household     75         2
# 12         Pen  Stationary      5        10
# 13      Pencil  Stationary      2        10
# 14     T-Shirt     Clothes    250         3
# 15      Bottle   Household     80         2
# 16      Bucket   Household    200         1
# 17       Chips        Food     10        15
# 18       Juice        Food    100         4
# 19     Tissues     Hygiene     30         5

# %%
shopping.head(5)
# Out:
#       Product Category  Price  Quantity
# 0       Bread     Food     20         2
# 1        Milk     Food     60         5
# 2     Biscuit     Food     20         2
# 3  Bourn-Vita     Food     70         1
# 4       Maggi     Food     20         5

# %%
len(shopping)
# Out:
# 20

# %%
shopping.shape
# Out:
# (20, 4)

# %%
shopping['Category'].unique()
# Out:
# array(['Food', 'Hygiene', 'Household', 'Stationary', 'Clothes'],
#       dtype=object)

# %%
shopping[['Product','Category']]
# Out:
#        Product    Category
# 0        Bread        Food
# 1         Milk        Food
# 2      Biscuit        Food
# 3   Bourn-Vita        Food
# 4        Maggi        Food
# 5          Tea        Food
# 6         Soap     Hygiene
# 7        Brush     Hygiene
# 8    Detergent   Household
# 9     Hair-Oil     Hygiene
# 10     Perfume     Hygiene
# 11  Tiffin Box   Household
# 12         Pen  Stationary
# 13      Pencil  Stationary
# 14     T-Shirt     Clothes
# 15      Bottle   Household
# 16      Bucket   Household
# 17       Chips        Food
# 18       Juice        Food
# 19     Tissues     Hygiene

# %%
# Multiplying two Columns to get Total Price for an item
Total = shopping['Price']*shopping['Quantity']

# %%
# Adding a new Column to the Dataframe
shopping['Total Price'] = Total  
shopping
# Out:
#        Product    Category  Price  Quantity  Total Price
# 0        Bread        Food     20         2           40
# 1         Milk        Food     60         5          300
# 2      Biscuit        Food     20         2           40
# 3   Bourn-Vita        Food     70         1           70
# 4        Maggi        Food     20         5          100
# 5          Tea        Food    120         1          120
# 6         Soap     Hygiene     40         4          160
# 7        Brush     Hygiene     30         2           60
# 8    Detergent   Household     80         1           80
# 9     Hair-Oil     Hygiene    100         1          100
# 10     Perfume     Hygiene    150         1          150
# 11  Tiffin Box   Household     75         2          150
# 12         Pen  Stationary      5        10           50
# 13      Pencil  Stationary      2        10           20
# 14     T-Shirt     Clothes    250         3          750
# 15      Bottle   Household     80         2          160
# 16      Bucket   Household    200         1          200
# 17       Chips        Food     10        15          150
# 18       Juice        Food    100         4          400
# 19     Tissues     Hygiene     30         5          150

# %%
shopping.to_csv('GroceryV2.csv', header= True)

# %%
#Adding Values in Total Price Columm to get total expenditure
totalExpenditure = shopping[['Total Price', 'Quantity', 'Price']].sum() 
totalExpenditure
#print(type(totalExpenditure))
# Out:
# Total Price    3250
# Quantity         77
# Price          1462
# dtype: int64

# %%
#dir(shopping)
shopping
# Out:
#        Product    Category  Price  Quantity  Total Price
# 0        Bread        Food     20         2           40
# 1         Milk        Food     60         5          300
# 2      Biscuit        Food     20         2           40
# 3   Bourn-Vita        Food     70         1           70
# 4        Maggi        Food     20         5          100
# 5          Tea        Food    120         1          120
# 6         Soap     Hygiene     40         4          160
# 7        Brush     Hygiene     30         2           60
# 8    Detergent   Household     80         1           80
# 9     Hair-Oil     Hygiene    100         1          100
# 10     Perfume     Hygiene    150         1          150
# 11  Tiffin Box   Household     75         2          150
# 12         Pen  Stationary      5        10           50
# 13      Pencil  Stationary      2        10           20
# 14     T-Shirt     Clothes    250         3          750
# 15      Bottle   Household     80         2          160
# 16      Bucket   Household    200         1          200
# 17       Chips        Food     10        15          150
# 18       Juice        Food    100         4          400
# 19     Tissues     Hygiene     30         5          150

# %%
#Sorting Data in decreasing order of item price
shoppingSorted = shopping.sort_values('Price',ascending = False)    
shoppingSorted
# Out:
#        Product    Category  Price  Quantity  Total Price
# 14     T-Shirt     Clothes    250         3          750
# 16      Bucket   Household    200         1          200
# 10     Perfume     Hygiene    150         1          150
# 5          Tea        Food    120         1          120
# 18       Juice        Food    100         4          400
# 9     Hair-Oil     Hygiene    100         1          100
# 15      Bottle   Household     80         2          160
# 8    Detergent   Household     80         1           80
# 11  Tiffin Box   Household     75         2          150
# 3   Bourn-Vita        Food     70         1           70
# 1         Milk        Food     60         5          300
# 6         Soap     Hygiene     40         4          160
# 19     Tissues     Hygiene     30         5          150
# 7        Brush     Hygiene     30         2           60
# 4        Maggi        Food     20         5          100
# 2      Biscuit        Food     20         2           40
# 0        Bread        Food     20         2           40
# 17       Chips        Food     10        15          150
# 12         Pen  Stationary      5        10           50
# 13      Pencil  Stationary      2        10           20

# %%
shopping[['Price','Quantity','Total Price']].agg(['sum','mean','max','min','count','median','var'])    #Aggregation in Pandas
# Out:
#               Price   Quantity   Total Price
# sum     1462.000000  77.000000   3250.000000
# mean      73.100000   3.850000    162.500000
# max      250.000000  15.000000    750.000000
# min        2.000000   1.000000     20.000000
# count     20.000000  20.000000     20.000000
# median    65.000000   2.000000    135.000000
# var     4430.621053  14.239474  27419.736842

# %%
shopping.describe()
# Out:
#            Price   Quantity  Total Price
# count   20.00000  20.000000     20.00000
# mean    73.10000   3.850000    162.50000
# std     66.56291   3.773523    165.58906
# min      2.00000   1.000000     20.00000
# 25%     20.00000   1.000000     67.50000
# 50%     65.00000   2.000000    135.00000
# 75%    100.00000   5.000000    160.00000
# max    250.00000  15.000000    750.00000

# %%
#Groupby in Pandas
#All products grouped according to the category
Categories = shopping.groupby('Category')
#Total expenditure per category
Categories['Total Price'].sum()
# Out:
# Category
# Clothes        750
# Food          1220
# Household      590
# Hygiene        620
# Stationary      70
# Name: Total Price, dtype: int64

# %%
#Total counts per category
Categories['Total Price'].count()
# Out:
# Category
# Clothes       1
# Food          8
# Household     4
# Hygiene       5
# Stationary    2
# Name: Total Price, dtype: int64

# %%
shopping.head()
# Out:
#       Product Category  Price  Quantity  Total Price
# 0       Bread     Food     20         2           40
# 1        Milk     Food     60         5          300
# 2     Biscuit     Food     20         2           40
# 3  Bourn-Vita     Food     70         1           70
# 4       Maggi     Food     20         5          100

# %%
#Broadcasting in Pandas Dataframe
 #Increase the quantity of each product by 1
shopping['Quantity'] += 1

# %%
shopping
# Out:
#        Product    Category  Price  Quantity  Total Price
# 0        Bread        Food     20         3           40
# 1         Milk        Food     60         6          300
# 2      Biscuit        Food     20         3           40
# 3   Bourn-Vita        Food     70         2           70
# 4        Maggi        Food     20         6          100
# 5          Tea        Food    120         2          120
# 6         Soap     Hygiene     40         5          160
# 7        Brush     Hygiene     30         3           60
# 8    Detergent   Household     80         2           80
# 9     Hair-Oil     Hygiene    100         2          100
# 10     Perfume     Hygiene    150         2          150
# 11  Tiffin Box   Household     75         3          150
# 12         Pen  Stationary      5        11           50
# 13      Pencil  Stationary      2        11           20
# 14     T-Shirt     Clothes    250         4          750
# 15      Bottle   Household     80         3          160
# 16      Bucket   Household    200         2          200
# 17       Chips        Food     10        16          150
# 18       Juice        Food    100         5          400
# 19     Tissues     Hygiene     30         6          150

# %%
#deleting columns from a Dataframe

shopping.drop(['Total Price'],axis = 1)
# Out:
#        Product    Category  Price  Quantity
# 0        Bread        Food     20         3
# 1         Milk        Food     60         6
# 2      Biscuit        Food     20         3
# 3   Bourn-Vita        Food     70         2
# 4        Maggi        Food     20         6
# 5          Tea        Food    120         2
# 6         Soap     Hygiene     40         5
# 7        Brush     Hygiene     30         3
# 8    Detergent   Household     80         2
# 9     Hair-Oil     Hygiene    100         2
# 10     Perfume     Hygiene    150         2
# 11  Tiffin Box   Household     75         3
# 12         Pen  Stationary      5        11
# 13      Pencil  Stationary      2        11
# 14     T-Shirt     Clothes    250         4
# 15      Bottle   Household     80         3
# 16      Bucket   Household    200         2
# 17       Chips        Food     10        16
# 18       Juice        Food    100         5
# 19     Tissues     Hygiene     30         6

# %%
#Combining data frames

shoppingNew = pd.read_csv('Grocery2.csv')
shoppingNew
# Out:
#        Products   Category  Price  Quantity
# 0         Jeans    Clothes    400         2
# 1     Chocolate       Food     50         4
# 2  Air Freshner  Household     80         2
# 3        Coffee       Food    120         1

# %%
shopping.head()
# Out:
#       Product Category  Price  Quantity  Total Price
# 0       Bread     Food     20         3           40
# 1        Milk     Food     60         6          300
# 2     Biscuit     Food     20         3           40
# 3  Bourn-Vita     Food     70         2           70
# 4       Maggi     Food     20         6          100

# %%
shoppingFinal = pd.concat([shopping,shoppingNew])

# %%
shoppingFinal
# Out:
#       Category  Price     Product      Products  Quantity  Total Price
# 0         Food     20       Bread           NaN         3         40.0
# 1         Food     60        Milk           NaN         6        300.0
# 2         Food     20     Biscuit           NaN         3         40.0
# 3         Food     70  Bourn-Vita           NaN         2         70.0
# 4         Food     20       Maggi           NaN         6        100.0
# 5         Food    120         Tea           NaN         2        120.0
# 6      Hygiene     40        Soap           NaN         5        160.0
# 7      Hygiene     30       Brush           NaN         3         60.0
# 8    Household     80   Detergent           NaN         2         80.0
# 9      Hygiene    100    Hair-Oil           NaN         2        100.0
# 10     Hygiene    150     Perfume           NaN         2        150.0
# 11   Household     75  Tiffin Box           NaN         3        150.0
# 12  Stationary      5         Pen           NaN        11         50.0
# 13  Stationary      2      Pencil           NaN        11         20.0
# 14     Clothes    250     T-Shirt           NaN         4        750.0
# 15   Household     80      Bottle           NaN         3        160.0
# 16   Household    200      Bucket           NaN         2        200.0
# 17        Food     10       Chips           NaN        16        150.0
# 18        Food    100       Juice           NaN         5        400.0
# 19     Hygiene     30     Tissues           NaN         6        150.0
# 0      Clothes    400         NaN         Jeans         2          NaN
# 1         Food     50         NaN     Chocolate         4          NaN
# 2    Household     80         NaN  Air Freshner         2          NaN
# 3         Food    120         NaN        Coffee         1          NaN

# %%
#Resetting the row index

shoppingFinal = shoppingFinal.reset_index(drop = True)
shoppingFinal
# Out:
#       Category  Price     Product      Products  Quantity  Total Price
# 0         Food     20       Bread           NaN         3         40.0
# 1         Food     60        Milk           NaN         6        300.0
# 2         Food     20     Biscuit           NaN         3         40.0
# 3         Food     70  Bourn-Vita           NaN         2         70.0
# 4         Food     20       Maggi           NaN         6        100.0
# 5         Food    120         Tea           NaN         2        120.0
# 6      Hygiene     40        Soap           NaN         5        160.0
# 7      Hygiene     30       Brush           NaN         3         60.0
# 8    Household     80   Detergent           NaN         2         80.0
# 9      Hygiene    100    Hair-Oil           NaN         2        100.0
# 10     Hygiene    150     Perfume           NaN         2        150.0
# 11   Household     75  Tiffin Box           NaN         3        150.0
# 12  Stationary      5         Pen           NaN        11         50.0
# 13  Stationary      2      Pencil           NaN        11         20.0
# 14     Clothes    250     T-Shirt           NaN         4        750.0
# 15   Household     80      Bottle           NaN         3        160.0
# 16   Household    200      Bucket           NaN         2        200.0
# 17        Food     10       Chips           NaN        16        150.0
# 18        Food    100       Juice           NaN         5        400.0
# 19     Hygiene     30     Tissues           NaN         6        150.0
# 20     Clothes    400         NaN         Jeans         2          NaN
# 21        Food     50         NaN     Chocolate         4          NaN
# 22   Household     80         NaN  Air Freshner         2          NaN
# 23        Food    120         NaN        Coffee         1          NaN

# %%
#Altering the labels/Column headers

shoppingFinal = shoppingFinal.rename(columns = {'Product': 'Item'})
shoppingFinal.head(3)
# Out:
#   Category  Price     Item Products  Quantity  Total Price
# 0     Food     20    Bread      NaN         3         40.0
# 1     Food     60     Milk      NaN         6        300.0
# 2     Food     20  Biscuit      NaN         3         40.0

# %%
#Reindexing the columns 

shoppingFinal.reindex(columns = ['Item','Category','Price','Quantity','Total Price']).head(3)
# Out:
#       Item Category  Price  Quantity  Total Price
# 0    Bread     Food     20         3         40.0
# 1     Milk     Food     60         6        300.0
# 2  Biscuit     Food     20         3         40.0

# %% [markdown]
# ## Data Plotting in Pandas

# %%
globalTemp = pd.read_csv('GlobalTemperatures.csv')
globalTemp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN

# %%
#Histogram

hist = globalTemp['LandAverageTemperature'].plot(kind = 'hist',figsize = (12, 8)) 
hist.set_xlabel("Average Land Temperature")
hist.set_ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %%
populationData = pd.read_csv('Demographicdata.csv',index_col = 0)

# %%
populationData.head()
# Out:
#            Life expectancy  Population(in millions)  Total Area(in miles)
# Lithuania             72.1                     3.28                 65300
# Latvia                72.2                     2.23                 64589
# Bulgaria              73.5                     7.35                110879
# Romania               73.8                    21.30                238391
# Estonia               74.4                     1.34                 45228

# %%
#Bar Graph

populationData['Population(in millions)'].plot(kind = 'bar', figsize = (12, 6), title = 'Population(in millions)')
